# %%
import pandas as pd
data = pd.read_csv('fb.csv')

# %%
data.shape
# Out:
# (500, 19)

# %%
data.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data.iloc[2:10,:]
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
# 5            139441  Status         2          12             1          9
# 6            139441   Photo         3          12             1          3
# 7            139441   Photo         3          12             7          9
# 8            139441  Status         2          12             7          3
# 9            139441   Photo         3          12             6         10
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# ...

# %%
data.iloc[2:10,1:5]
# Out:
#      Type  Category  Post Month  Post Weekday
# 2   Photo         3          12             3
# 3   Photo         2          12             2
# 4   Photo         2          12             2
# 5  Status         2          12             1
# 6   Photo         3          12             1
# 7   Photo         3          12             7
# 8  Status         2          12             7
# 9   Photo         3          12             6

# %%
data.loc[:,'Type']
# Out:
# 0       Photo
# 1      Status
# 2       Photo
# 3       Photo
# 4       Photo
#         ...
# 495     Photo
# 496     Photo
# 497     Photo
# 498     Photo
# 499     Photo
# Name: Type, Length: 500, dtype: object

# %%
data.loc[2:10,'Type']
# Out:
# 2      Photo
# 3      Photo
# 4      Photo
# 5     Status
# 6      Photo
# 7      Photo
# 8     Status
# 9      Photo
# 10    Status
# Name: Type, dtype: object

# %%
X = data[['Type', 'Category', 'comment', 'like', 'share']]

# %%
X
# Out:
#        Type  Category  comment    like  share
# 0     Photo         2        4    79.0   17.0
# 1    Status         2        5   130.0   29.0
# 2     Photo         3        0    66.0   14.0
# 3     Photo         2       58  1572.0  147.0
# 4     Photo         2       19   325.0   49.0
# ..      ...       ...      ...     ...    ...
# 495   Photo         3        5    53.0   26.0
# 496   Photo         2        0    53.0   22.0
# 497   Photo         1        4    93.0   18.0
# 498   Photo         3        7    91.0   38.0
# 499   Photo         2        0    91.0   28.0
#
# [500 rows x 5 columns]

# %%
Z = X[X['like'] > 100]
Z
# Out:
#        Type  Category  comment    like  share
# 1    Status         2        5   130.0   29.0
# 3     Photo         2       58  1572.0  147.0
# 4     Photo         2       19   325.0   49.0
# 5    Status         2        1   152.0   33.0
# 6     Photo         3        3   249.0   27.0
# ..      ...       ...      ...     ...    ...
# 488   Photo         3       21   277.0   80.0
# 491   Photo         3        1   105.0   46.0
# 492    Link         1        0   128.0    9.0
# 493   Photo         3       17   185.0   55.0
# 494   Photo         3       10   125.0   41.0
#
# [252 rows x 5 columns]

# %%
Z = X[(X['like']>100)&(X['share']>40)]
Z
# Out:
#        Type  Category  comment    like  share
# 3     Photo         2       58  1572.0  147.0
# 4     Photo         2       19   325.0   49.0
# 26   Status         2       10   412.0   72.0
# 28    Photo         2       36   523.0   63.0
# 32    Photo         3        2   155.0   47.0
# ..      ...       ...      ...     ...    ...
# 480   Photo         2       56   360.0   99.0
# 488   Photo         3       21   277.0   80.0
# 491   Photo         3        1   105.0   46.0
# 493   Photo         3       17   185.0   55.0
# 494   Photo         3       10   125.0   41.0
#
# [84 rows x 5 columns]

# %%
Z.to_csv('trialOutput.csv',index=False)
Z.to_html('trialoutput.html',index=False)

# %%
Y = data.drop(['Type', 'Category', 'comment', 'like', 'share'], axis=1)
Y
# Out:
#      Page total likes  Post Month  Post Weekday  Post Hour  Paid  \
# 0              139441          12             4          3   0.0
# 1              139441          12             3         10   0.0
# 2              139441          12             3          3   0.0
# 3              139441          12             2         10   1.0
# 4              139441          12             2          3   0.0
# ..                ...         ...           ...        ...   ...
# 495             85093           1             7          2   0.0
# 496             81370           1             5          8   0.0
# 497             81370           1             5          2   0.0
# 498             81370           1             4         11   0.0
# 499             81370           1             4          4   NaN
#
#      Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0                         2752                             5091
# ...

# %%
Y = data.drop([1,2,3])
Y
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# 7              139441   Photo         3          12             7          9
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
Z.sort_values(by = 'comment',ascending=True)
Z.T
# Out:
#              3      4       26     28     32     56     67     71      72   \
# Type       Photo  Photo  Status  Photo  Photo  Photo  Photo  Video  Status
# Category       2      2       2      2      3      1      1      1       3
# comment       58     19      10     36      2      2     20     17       3
# like      1572.0  325.0   412.0  523.0  155.0  164.0  697.0  449.0   226.0
# share      147.0   49.0    72.0   63.0   47.0   54.0   70.0   84.0    44.0
#
#             73   ...    462    469    471    473    476    480    488    491  \
# Type      Photo  ...  Photo  Photo  Photo  Photo  Photo  Photo  Photo  Photo
# Category      1  ...      3      3      3      3      1      2      3      3
# comment      14  ...     19     10      7      4      7     56     21      1
# like      172.0  ...  214.0  193.0  160.0  136.0  579.0  360.0  277.0  105.0
# share      47.0  ...   78.0   61.0   57.0   42.0   47.0   99.0   80.0   46.0
#
#             493    494
# Type      Photo  Photo
# ...

# %%
Z.melt(id_vars = ['Category', 'Type'])
# Out:
#      Category    Type variable  value
# 0           2   Photo  comment   58.0
# 1           2   Photo  comment   19.0
# 2           2  Status  comment   10.0
# 3           2   Photo  comment   36.0
# 4           3   Photo  comment    2.0
# ..        ...     ...      ...    ...
# 247         2   Photo    share   99.0
# 248         3   Photo    share   80.0
# 249         3   Photo    share   46.0
# 250         3   Photo    share   55.0
# 251         3   Photo    share   41.0
#
# [252 rows x 4 columns]

# %%
pd.get_dummies(Z)
# Out:
#      Category  comment    like  share  Type_Link  Type_Photo  Type_Status  \
# 3           2       58  1572.0  147.0      False        True        False
# 4           2       19   325.0   49.0      False        True        False
# 26          2       10   412.0   72.0      False       False         True
# 28          2       36   523.0   63.0      False        True        False
# 32          3        2   155.0   47.0      False        True        False
# ..        ...      ...     ...    ...        ...         ...          ...
# 480         2       56   360.0   99.0      False        True        False
# 488         3       21   277.0   80.0      False        True        False
# 491         3        1   105.0   46.0      False        True        False
# 493         3       17   185.0   55.0      False        True        False
# 494         3       10   125.0   41.0      False        True        False
#
#      Type_Video
# 3         False
# 4         False
# 26        False
# ...

# %%
dir(Z)
# Out:
# ['Category',
#  'T',
#  'Type',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
# ...

# %%
len(dir(Z))
# Out:
# 445
